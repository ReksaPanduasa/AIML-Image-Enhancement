# %%
''' Image Enhancement OpenCV '''
#--------------------------------
# Date : 18-06-2020
# Project : Image Enhancement OpenCV
# Category : Image Processing
# Company : weblineindia
# Department : AI/ML
#--------------------------------
import os
import cv2
from scipy import ndimage

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
PATH = '/content/drive/MyDrive/College/Sem5/AIL/proyek/dataset'
RESULTS = '/content/drive/MyDrive/College/Sem5/AIL/proyek/hasil'

# %%
print(os.listdir(PATH))
# Out:
# ['image1.jpg', 'image2.jpg']

# %%
for filename in os.listdir(PATH):
    try:
        image = cv2.imread(os.path.join(PATH, filename))
        if image is not None:
            print(f"Processing {filename}")
            # ... rest of the code
        else:
            print(f"Skipping {filename}, image not loaded")
    except Exception as e:
        print(f"Error processing {filename}: {str(e)}")
# Out:
# Processing image1.jpg
# Processing image2.jpg

# %%
os.makedirs(RESULTS, exist_ok=True)

# %%
"""
# Removes noise and imporves image quality.
"""
def enhanceImage(path):

	for filename in os.listdir(path):

		try:
			image = cv2.imread(os.path.join(path, filename))
			if image is not None:
				# Convert image to gray scale
				gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

				# Non-Linear filter for noise removal
				deNoised = ndimage.median_filter(gray_image, 3)

				#Histogram Equalizer
				#High pass filter for improving the contrast of the image
				clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
				highPass = clahe.apply(deNoised)

				#Gamma Transformation
				#Prevent bleaching or darkening of images
				gamma = highPass/255.0
				gammaFilter = cv2.pow(gamma,1.5)
				gammaFilter = gammaFilter * 255

				cv2.imwrite(os.path.join(RESULTS, filename), gammaFilter)
				print(f"Saved enhanced image: {filename}")
			else:
				print(f"Skipping {filename}, image not loaded")
		except Exception as e:
			print(f"Error processing {filename}: {str(e)}")

# %%
print("--------IMAGE ENHANCEMENT TECHNIQUE----------")
print("---------------------------------------------")
print("--------INITIALIZED IMAGE PROCESSING---------")
# Enhance Image Quality
enhanceImage(PATH)
print("--------IMAGE PROCESSING COMPLETED-----------")
# Out:
# --------IMAGE ENHANCEMENT TECHNIQUE----------
# ---------------------------------------------
# --------INITIALIZED IMAGE PROCESSING---------
# Saved enhanced image: image1.jpg
# Saved enhanced image: image2.jpg
# --------IMAGE PROCESSING COMPLETED-----------
